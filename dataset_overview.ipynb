# %% [markdown]
# ### Notebook for listing all datasets
#
# Lists available datasets which might be helpful for finetuning specific detectors. Also creates a fiftyone session suitable for exploring them.

# %%
import fiftyone as fo
import fiftyone.zoo as foz
from fiftyone import ViewField as F
import os

# %%
dataset_dirs = ['Bordeaux', 'Bonn', 'image_search']
dataset_type = fo.types.COCODetectionDataset
data_path = 'data/robocup_bordeaux_2023/robocup_data/coco_datasets'
num_datasets, num_frames, num_samples = 0, 0, 0
for dataset_dir in dataset_dirs:
    print('Loading datasets in directory \'' + dataset_dir + '\'')
    datasets = os.listdir(os.path.join(data_path, dataset_dir))
    print('Found datasets:', datasets, '\n')
    for dataset in datasets:
        num_datasets += 1
        print('Loading dataset ' + dataset)
        train_dataset = fo.Dataset.from_dir(
            dataset_type=dataset_type,
            data_path=os.path.join(data_path, dataset_dir, dataset, 'train'),
            labels_path=os.path.join(data_path, dataset_dir, dataset, 'annotations', 'instances_Train.json'),
            name=dataset + '_train',
        )
        num_frames += train_dataset.count()
        num_samples += sum(train_dataset.count_values("segmentations.detections.label").values())
        print('--> Available training labels are: \n', train_dataset.distinct("segmentations.detections.label"))
        if os.path.exists(os.path.join(data_path, dataset_dir, dataset, 'val')):
            valid_dataset = fo.Dataset.from_dir(
                dataset_type=dataset_type,
                data_path=os.path.join(data_path, dataset_dir, dataset, 'val'),
                labels_path=os.path.join(data_path, dataset_dir, dataset, 'annotations', 'instances_Validation.json'),
                name=dataset + '_valid',
            )
            num_frames += valid_dataset.count()
            num_samples += sum(valid_dataset.count_values("segmentations.detections.label").values())
            print('--> Available validation labels are: \n', valid_dataset.distinct("segmentations.detections.label"))
        print()
# Out:
# Loading datasets in directory 'Bordeaux'
# Found datasets: ['bordeaux_day_2_coco', 'bordeaux_clean_table_coco', 'bordeaux_day_1_coco', 'bordeaux_bags_coco', 'arena_furniture_coco']
#
# Loading dataset bordeaux_day_2_coco
#  100% |█████████████████| 253/253 [5.7s elapsed, 0s remaining, 35.1 samples/s]
# --> Available training labels are:
#  ['apple', 'bag', 'banana', 'bed', 'bin', 'bowl', 'candle', 'cereals', 'chair', 'chocolate_pudding_box', 'cola', 'couch', 'couch_table', 'cracker_box', 'cupboard', 'decoration', 'dice', 'dishwasher', 'dishwasher_tray', 'door', 'door_handle', 'dresser', 'fridge', 'iced_tea', 'jacket_stand', 'juice_pack', 'lamp', 'lemon', 'milk_bottle', 'mustard_bottle', 'orange', 'orange_juice', 'peach', 'pear', 'person', 'plum', 'potted_meat_can', 'pringles', 'red_wine', 'rubiks_cube', 'shelf', 'shelf_door', 'sink', 'soccer_ball', 'sponge', 'strawberry', 'strawberry_gelatin_box', 'sugar_box', 'table', 'tennis_ball', 'tomato_soup_can', 'tray', 'tropical_juice', 'tuna_fish_can', 'tv']
#  100% |███████████████████| 32/32 [573.3ms elapsed, 0s remaining, 55.8 samples/s]
# --> Available validation labels are:
#  ['banana', 'bed', 'bin', 'bowl', 'candle', 'cereals', 'chair', 'chocolate_pudding_box', 'cola', 'couch_table', 'cracker_box', 'cupboard', 'decoration', 'dishwasher', 'door', 'door_handle', 'fridge', 'iced_tea', 'jacket_stand', 'juice_pack', 'lamp', 'lemon', 'milk_bottle', 'mustard_bottle', 'orange', 'orange_juice', 'pear', 'person', 'potted_meat_can', 'red_wine', 'shelf', 'shelf_door', 'sponge', 'strawberry', 'strawberry_gelatin_box', 'sugar_box', 'table', 'tomato_soup_can', 'tray', 'tropical_juice', 'tuna_fish_can', 'tv']
#
# Loading dataset bordeaux_clean_table_coco
#  100% |█████████████████| 100/100 [2.8s elapsed, 0s remaining, 38.3 samples/s]
# --> Available training labels are:
#  ['bin', 'bowl', 'cereals', 'chair', 'couch_table', 'cupboard', 'decoration', 'dishwasher', 'dishwasher_slot', 'dishwasher_tab', 'dishwasher_tray', 'fork', 'fridge', 'knife', 'milk_bottle', 'mug', 'orange_juice', 'person', 'plate', 'shelf', 'shelf_door', 'spoon', 'table', 'tropical_juice']
#  100% |███████████████████| 20/20 [417.3ms elapsed, 0s remaining, 48.1 samples/s]
# --> Available validation labels are:
#  ['bin', 'bowl', 'cereals', 'chair', 'couch_table', 'decoration', 'dishwasher', 'dishwasher_slot', 'dishwasher_tab', 'dishwasher_tray', 'fork', 'knife', 'milk_bottle', 'mug', 'orange_juice', 'person', 'plate', 'shelf', 'shelf_door', 'spoon', 'table', 'tropical_juice']
#
# Loading dataset bordeaux_day_1_coco
#  100% |█████████████████| 100/100 [2.5s elapsed, 0s remaining, 39.2 samples/s]
# --> Available training labels are:
#  ['apple', 'bed', 'bin', 'chair', 'chipster', 'chocolate_pudding_box', 'cleanser_bottle', 'coffee_can', 'couch', 'couch_table', 'cupboard', 'dishwasher', 'door', 'dresser', 'fork', 'fridge', 'fridge_handle', 'jacket_stand', 'knife', 'lamp', 'mustard_bottle', 'person', 'pringles', 'rubiks_cube', 'shelf', 'sink', 'spoon', 'strawberry_gelatin_box', 'sugar_box', 'table', 'tv']
#  100% |███████████████████| 25/25 [692.4ms elapsed, 0s remaining, 36.2 samples/s]
# --> Available validation labels are:
#  ['apple', 'bin', 'chair', 'chipster', 'chocolate_pudding_box', 'cleanser_bottle', 'coffee_can', 'couch', 'couch_table', 'cupboard', 'dishwasher', 'door', 'door_handle', 'fork', 'knife', 'lamp', 'mustard_bottle', 'person', 'pringles', 'rubiks_cube', 'shelf', 'sink', 'spoon', 'strawberry_gelatin_box', 'sugar_box', 'table', 'tv']
#
# Loading dataset bordeaux_bags_coco
#  100% |███████████████████| 80/80 [382.7ms elapsed, 0s remaining, 209.0 samples/s]
# --> Available training labels are:
#  ['bag']
#
# Loading dataset arena_furniture_coco
#  100% |█████████████████| 100/100 [1.4s elapsed, 0s remaining, 71.6 samples/s]
# --> Available training labels are:
#  ['bed', 'chair', 'couch', 'couch_table', 'cupboard', 'dishwasher', 'dishwasher_slot', 'dishwasher_tray', 'door', 'door_handle', 'dresser', 'fridge', 'fridge_handle', 'jacket_stand', 'lamp', 'microwave_oven', 'person', 'shelf', 'sink', 'table', 'tv']
#  100% |███████████████████| 50/50 [645.0ms elapsed, 0s remaining, 77.5 samples/s]
# --> Available validation labels are:
#  ['bed', 'bin', 'chair', 'couch', 'couch_table', 'cupboard', 'dishwasher', 'dishwasher_slot', 'dishwasher_tray', 'door', 'door_handle', 'dresser', 'fridge', 'fridge_handle', 'jacket_stand', 'lamp', 'person', 'shelf', 'sink', 'table', 'tv']
#
# Loading datasets in directory 'Bonn'
# Found datasets: ['drinks_ais_coco', 'base_dataset_ais_coco', 'ycb_test_ais_coco', 'difficult_objects_ais_coco', 'robocup23_ais_coco', 'kitchenware_ais_coco']
#
# Loading dataset drinks_ais_coco
#  100% |█████████████████| 130/130 [1.2s elapsed, 0s remaining, 105.5 samples/s]
# --> Available training labels are:
#  ['almdudler', 'apple_juice', 'booster', 'coke', 'iso_drink', 'orange_juice']
#  100% |███████████████████| 14/14 [170.6ms elapsed, 0s remaining, 82.8 samples/s]
# --> Available validation labels are:
#  ['almdudler', 'apple_juice', 'booster', 'coke', 'iso_drink', 'orange_juice']
#
# Loading dataset base_dataset_ais_coco
#  100% |█████████████████| 507/507 [11.9s elapsed, 0s remaining, 49.2 samples/s]
# --> Available training labels are:
#  ['almdudler', 'apple_juice', 'bag', 'bell_pepper', 'booster', 'bowl', 'brush', 'cereals', 'chair', 'chamomile_tea', 'chocolate_candy', 'coke', 'cookies', 'couch', 'cup', 'dishwasher_tab', 'fork', 'iso_drink', 'ketchup', 'kidney_bean_can', 'kleenex', 'knife', 'mustard', 'noodles_chicken_flavor', 'noodles_duck_flavor', 'orange_juice', 'person', 'plate', 'pringles', 'sparkling_water', 'sponge', 'spoon', 'table', 'tomato_can', 'tuc', 'windex', 'wipes']
#  100% |███████████████████| 30/30 [1.1s elapsed, 0s remaining, 26.2 samples/s]
# --> Available validation labels are:
#  ['almdudler', 'apple_juice', 'bag', 'bell_pepper', 'booster', 'bowl', 'brush', 'cereals', 'chair', 'chamomile_tea', 'chocolate_candy', 'coke', 'cookies', 'couch', 'cup', 'dishwasher_tab', 'fork', 'iso_drink', 'ketchup', 'kidney_bean_can', 'kleenex', 'knife', 'mustard', 'noodles_chicken_flavor', 'noodles_duck_flavor', 'orange_juice', 'person', 'plate', 'pringles', 'sparkling_water', 'sponge', 'spoon', 'table', 'tomato_can', 'tuc', 'windex', 'wipes']
#
# Loading dataset ycb_test_ais_coco
#  100% |███████████████████| 30/30 [774.5ms elapsed, 0s remaining, 38.8 samples/s]
# --> Available training labels are:
#  ['banana', 'baseball', 'chocolate_pudding_box', 'golf_ball', 'mustard_bottle', 'orange', 'person', 'plate', 'pringles', 'racquet_ball', 'soccer_ball', 'strawberry', 'strawberry_gelatin_box', 'table', 'tomato_soup_can', 'tuna_fish_can']
#  100% |███████████████████| 10/10 [273.3ms elapsed, 0s remaining, 36.6 samples/s]
# --> Available validation labels are:
#  ['banana', 'baseball', 'chocolate_pudding_box', 'golf_ball', 'mustard_bottle', 'orange', 'person', 'plate', 'pringles', 'racquet_ball', 'soccer_ball', 'strawberry', 'table', 'tomato_soup_can', 'tuna_fish_can']
#
# Loading dataset difficult_objects_ais_coco
#  100% |█████████████████| 132/132 [2.9s elapsed, 0s remaining, 49.3 samples/s]
# --> Available training labels are:
#  ['almdudler', 'apple', 'apple_juice', 'bowl', 'cereals', 'chair', 'coffee_can', 'coke', 'cracker_box', 'fork', 'iso_drink', 'knife', 'lemon', 'mug', 'peach', 'pear', 'plate', 'pringles', 'spoon', 'strawberry', 'strawberry_gelatin_box', 'sugar_box', 'table', 'tennis_ball', 'tomato_soup_can']
#  100% |███████████████████| 12/12 [289.7ms elapsed, 0s remaining, 41.6 samples/s]
# --> Available validation labels are:
#  ['almdudler', 'apple_juice', 'bowl', 'cereals', 'coffee_can', 'coke', 'cracker_box', 'fork', 'iso_drink', 'knife', 'lemon', 'mug', 'mustard_bottle', 'peach', 'pear', 'spoon', 'strawberry', 'strawberry_gelatin_box', 'sugar_box', 'tomato_soup_can']
#
# Loading dataset robocup23_ais_coco
#  100% |█████████████████| 300/300 [9.8s elapsed, 0s remaining, 29.8 samples/s]
# --> Available training labels are:
#  ['almdudler', 'apple', 'apple_juice', 'bag', 'banana', 'baseball', 'booster', 'bowl', 'cereals', 'chair', 'chocolate_pudding_box', 'cleanser_bottle', 'coffee_can', 'coke', 'cracker_box', 'dice', 'dishwasher_tab', 'fork', 'golf_ball', 'iso_drink', 'knife', 'lemon', 'milk_bottle', 'milk_carton', 'mug', 'mustard_bottle', 'orange', 'orange_juice', 'peach', 'pear', 'person', 'plate', 'plum', 'potted_meat_can', 'pringles', 'racquet_ball', 'rubiks_cube', 'soccer_ball', 'soft_ball', 'spoon', 'strawberry', 'strawberry_gelatin_box', 'sugar_box', 'table', 'tennis_ball', 'tomato_soup_can', 'tuna_fish_can']
#  100% |███████████████████| 30/30 [764.6ms elapsed, 0s remaining, 39.3 samples/s]
# --> Available validation labels are:
#  ['almdudler', 'apple', 'apple_juice', 'bag', 'banana', 'baseball', 'booster', 'bowl', 'cereals', 'chair', 'chocolate_pudding_box', 'cleanser_bottle', 'coffee_can', 'coke', 'cracker_box', 'dice', 'dishwasher_tab', 'fork', 'golf_ball', 'iso_drink', 'knife', 'lemon', 'milk_bottle', 'milk_carton', 'mug', 'mustard_bottle', 'orange', 'orange_juice', 'peach', 'pear', 'person', 'plate', 'plum', 'potted_meat_can', 'pringles', 'racquet_ball', 'rubiks_cube', 'soccer_ball', 'soft_ball', 'spoon', 'strawberry', 'strawberry_gelatin_box', 'sugar_box', 'table', 'tennis_ball', 'tomato_soup_can', 'tuna_fish_can']
#
# Loading dataset kitchenware_ais_coco
#  100% |█████████████████| 150/150 [2.5s elapsed, 0s remaining, 60.6 samples/s]
# --> Available training labels are:
#  ['cooker_plate', 'cooker_temp', 'grill_grate', 'grill_temp', 'pan', 'pan_handle', 'person', 'pizza_grill', 'pizza_handle', 'pizza_temp', 'pizza_time', 'table']
#  100% |███████████████████| 30/30 [381.6ms elapsed, 0s remaining, 78.9 samples/s]
# --> Available validation labels are:
#  ['chair', 'cooker_plate', 'cooker_temp', 'grill_grate', 'grill_temp', 'pan', 'pan_handle', 'pizza_grill', 'pizza_handle', 'pizza_temp', 'pizza_time', 'table']
#
# Loading datasets in directory 'image_search'
# Found datasets: ['cupboards', 'bags', 'fruits', 'soft_drinks', 'dishwasher_tabs', 'doors', 'milk', 'balls', 'furniture', 'cereals']
#
# Loading dataset cupboards
#  100% |███████████████████| 90/90 [1.7s elapsed, 0s remaining, 53.9 samples/s]
# --> Available training labels are:
#  ['chair', 'cupboard', 'cupboard_door', 'cupboard_handle', 'dishwasher', 'door', 'door_handle', 'person', 'table']
#  100% |█████████████████████| 9/9 [207.3ms elapsed, 0s remaining, 43.4 samples/s]
# --> Available validation labels are:
#  ['cupboard', 'cupboard_door', 'cupboard_handle', 'door', 'door_handle', 'person']
#
# Loading dataset bags
#  100% |███████████████████| 90/90 [1.8s elapsed, 0s remaining, 49.6 samples/s]
# --> Available training labels are:
#  ['bag', 'bell_pepper', 'person']
#  100% |███████████████████| 10/10 [156.4ms elapsed, 0s remaining, 64.5 samples/s]
# --> Available validation labels are:
#  ['bag']
#
# Loading dataset fruits
#  100% |███████████████████| 88/88 [3.1s elapsed, 0s remaining, 27.9 samples/s]
# --> Available training labels are:
#  ['apple', 'bag', 'banana', 'bell_pepper', 'chair', 'dishwasher', 'lemon', 'orange', 'orange_juice', 'peach', 'pear', 'person', 'plum', 'schweppes_lemon', 'strawberry', 'table']
#  100% |███████████████████| 10/10 [147.3ms elapsed, 0s remaining, 67.9 samples/s]
# --> Available validation labels are:
#  ['apple', 'banana', 'bell_pepper', 'chair', 'lemon', 'orange', 'orange_juice', 'pear', 'plum']
#
# Loading dataset soft_drinks
#  100% |███████████████████| 90/90 [2.7s elapsed, 0s remaining, 34.6 samples/s]
# --> Available training labels are:
#  ['7_up', 'chamomile_tea', 'coke', 'dr_pepper', 'fanta', 'ice_tea', 'mirinda', 'mountain_dew', 'orange_juice', 'pepsi', 'red_bull', 'schweppes_citrus', 'schweppes_lemon', 'schweppes_tonic', 'sprite']
#  100% |███████████████████| 10/10 [315.3ms elapsed, 0s remaining, 31.7 samples/s]
# --> Available validation labels are:
#  ['7_up', 'coke', 'fanta', 'grapefruit_juice', 'ice_tea', 'juice_mix', 'mirinda', 'mountain_dew', 'orange_juice', 'pepsi', 'schweppes_citrus', 'schweppes_lemon', 'schweppes_tonic', 'sprite']
#
# Loading dataset dishwasher_tabs
#  100% |███████████████████| 90/90 [571.9ms elapsed, 0s remaining, 157.7 samples/s]
# --> Available training labels are:
#  ['dishwasher', 'dishwasher_tab', 'person', 'plate', 'table']
#  100% |███████████████████| 10/10 [215.5ms elapsed, 0s remaining, 46.4 samples/s]
# --> Available validation labels are:
#  ['bowl', 'cup', 'dishwasher', 'dishwasher_tab', 'fork', 'knife', 'plate', 'spoon', 'table']
#
# Loading dataset doors
#  100% |███████████████████| 90/90 [1.3s elapsed, 0s remaining, 68.6 samples/s]
# --> Available training labels are:
#  ['door', 'door_handle']
#  100% |███████████████████| 10/10 [110.9ms elapsed, 0s remaining, 90.2 samples/s]
# --> Available validation labels are:
#  ['door', 'door_handle']
#
# Loading dataset milk
#  100% |███████████████████| 88/88 [602.2ms elapsed, 0s remaining, 146.1 samples/s]
# --> Available training labels are:
#  ['milk', 'person', 'sparkling_water']
#  100% |███████████████████| 12/12 [137.2ms elapsed, 0s remaining, 87.4 samples/s]
# --> Available validation labels are:
#  ['milk']
#
# Loading dataset balls
#  100% |███████████████████| 89/89 [1.5s elapsed, 0s remaining, 61.1 samples/s]
# --> Available training labels are:
#  ['baseball', 'golf_ball', 'person', 'racquetball', 'soccer_ball', 'soft_ball', 'tennis_ball']
#  100% |███████████████████| 11/11 [111.1ms elapsed, 0s remaining, 99.0 samples/s]
# --> Available validation labels are:
#  ['baseball', 'golf_ball', 'soccer_ball', 'tennis_ball']
#
# Loading dataset furniture
#  100% |███████████████████| 90/90 [1.1s elapsed, 0s remaining, 80.7 samples/s]
# --> Available training labels are:
#  ['armchair', 'chair', 'couch', 'cup', 'door', 'table']
#  100% |███████████████████| 10/10 [138.7ms elapsed, 0s remaining, 72.1 samples/s]
# --> Available validation labels are:
#  ['chair', 'couch', 'door', 'table']
#
# Loading dataset cereals
#  100% |███████████████████| 88/88 [1.3s elapsed, 0s remaining, 68.9 samples/s]
# --> Available training labels are:
#  ['cereals']
#  100% |███████████████████| 10/10 [119.0ms elapsed, 0s remaining, 84.1 samples/s]
# --> Available validation labels are:
#  ['cereals', 'strawberry']

# %%
print(f'Found a total of {num_samples} annotated object instances in {num_frames} frames from {num_datasets} datasets.')
# Out:
# Found a total of 30742 annotated object instances in 3130 frames from 21 datasets.

# %%
# The datasets can be explored right in this notebook, or alternatively under localhost:5151
# To select a dataset, use the menu near the top-left of the session.
session = fo.launch_app(train_dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=bed85939-53de-4474-8e8b-82939067c31d"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
